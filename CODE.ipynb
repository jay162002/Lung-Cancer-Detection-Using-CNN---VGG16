# %% [markdown]
# **Project on Lung Cancer Detection Using CNN**
#
# JAYDEEP DARJI

# %%
import numpy as np 
import pandas as pd 
import tensorflow as tf
from tensorflow.keras.layers import Conv2D,Dense,MaxPooling2D,Flatten,BatchNormalization,Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.applications import VGG16
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.resnet import preprocess_input
import matplotlib.pyplot as plt
import cv2 as cv
from sklearn.utils import shuffle
from sklearn.metrics import confusion_matrix,classification_report
from keras.utils import to_categorical

import os

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
from google.colab import drive
drive.mount('/content/drive')

# Define paths
train_path_str = '/content/drive/MyDrive/Data/train/'
val_path_str = '/content/drive/MyDrive/Data/valid/'
test_path_str = '/content/drive/MyDrive/Data/test/'
# Out:
# Mounted at /content/drive

# %%
test_classes = os.listdir(test_path_str)

# %%
input_shape = (224,224,3)
num_classes = 4

trainGenertor = ImageDataGenerator(
    preprocessing_function = preprocess_input,
    rotation_range = 10,
    width_shift_range = 0.3,
    height_shift_range = 0.3,
    shear_range = 0.2,
    zoom_range = 0.1,
    horizontal_flip = True,
    vertical_flip = True,
    dtype = 'float32'
)
valGenertor = ImageDataGenerator(
    preprocessing_function = preprocess_input,
    dtype = 'float32'
)

testGenertor = ImageDataGenerator(
    preprocessing_function = preprocess_input,
    dtype = 'float32'
)

# %%
train_data = trainGenertor.flow_from_directory(
    train_path_str,
    target_size = (224,224),
    batch_size = 16,
    class_mode = 'categorical'
)

val_data = valGenertor.flow_from_directory(
    val_path_str,
    target_size = (224,224),
    batch_size = 16,
    class_mode = 'categorical'
)

test_data = testGenertor.flow_from_directory(
    test_path_str,
    target_size = (224,224),
    batch_size = 16,
    class_mode = 'categorical',
    shuffle = False
)
# Out:
# Found 613 images belonging to 4 classes.
# Found 72 images belonging to 4 classes.
# Found 315 images belonging to 4 classes.

# %%
VGG16_model = VGG16(
    include_top = False,
    weights="imagenet",
    input_shape = input_shape
)
for layer in VGG16_model.layers :
  layer.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step

# %%
from keras.src.metrics.confusion_metrics import activations
model = Sequential()
model.add(VGG16_model)
model.add(BatchNormalization())
model.add(MaxPooling2D((2,2)))
model.add(Flatten())
model.add(Dense(1024,activation = 'relu'))
model.add(Dropout(0.3))
model.add(Dense(512,activation = 'relu'))
model.add(Dropout(0.3))
model.add(Dense(256,activation = 'relu'))
model.add(Dense(128,activation = 'relu'))
model.add(Dense(num_classes,activation = 'softmax'))
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ vgg16 (Functional)                   │ (None, 7, 7, 512)           │      14,714,688 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 7, 7, 512)           │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 3, 3, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 4608)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1024)                │       4,719,616 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 512)                 │         524,800 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 4)                   │             516 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 20,125,892 (76.77 MB)
#  Trainable params: 5,410,180 (20.64 MB)
#  Non-trainable params: 14,715,712 (56.14 MB)

# %%
model.compile(
    optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy']
)
callbacks = [
    tf.keras.callbacks.EarlyStopping(patience=5),
    tf.keras.callbacks.ModelCheckpoint('model.keras',save_best_only=True),
    tf.keras.callbacks.TensorBoard(log_dir='logs')
]

# %%
results = model.fit(train_data,validation_data=val_data,epochs=100,verbose = 1)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 385s 8s/step - accuracy: 0.3816 - loss: 1.8332 - val_accuracy: 0.4861 - val_loss: 1.8472
# Epoch 2/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 73s 297ms/step - accuracy: 0.4736 - loss: 1.2044 - val_accuracy: 0.3056 - val_loss: 1.4861
# Epoch 3/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 14s 298ms/step - accuracy: 0.5053 - loss: 1.1477 - val_accuracy: 0.4861 - val_loss: 1.0090
# Epoch 4/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 20s 303ms/step - accuracy: 0.5355 - loss: 0.9931 - val_accuracy: 0.4306 - val_loss: 1.0404
# Epoch 5/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 14s 321ms/step - accuracy: 0.5316 - loss: 1.0103 - val_accuracy: 0.4861 - val_loss: 0.9447
# Epoch 6/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 13s 293ms/step - accuracy: 0.5781 - loss: 0.9271 - val_accuracy: 0.5417 - val_loss: 1.0354
# Epoch 7/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 21s 301ms/step - accuracy: 0.6347 - loss: 0.7975 - val_accuracy: 0.6111 - val_loss: 0.9126
# Epoch 8/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 14s 300ms/step - accuracy: 0.6370 - loss: 0.8231 - val_accuracy: 0.5833 - val_loss: 0.9158
# Epoch 9/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 20s 294ms/step - accuracy: 0.6180 - loss: 0.8566 - val_accuracy: 0.6111 - val_loss: 0.7461
# Epoch 10/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 21s 306ms/step - accuracy: 0.6765 - loss: 0.7484 - val_accuracy: 0.6389 - val_loss: 0.8544
# Epoch 11/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 20s 289ms/step - accuracy: 0.6451 - loss: 0.7809 - val_accuracy: 0.4861 - val_loss: 1.4866
# Epoch 12/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 21s 302ms/step - accuracy: 0.6818 - loss: 0.7677 - val_accuracy: 0.6111 - val_loss: 0.8439
# Epoch 13/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 14s 308ms/step - accuracy: 0.7059 - loss: 0.6841 - val_accuracy: 0.5139 - val_loss: 1.3145
# Epoch 14/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 13s 300ms/step - accuracy: 0.7027 - loss: 0.6891 - val_accuracy: 0.5278 - val_loss: 0.9324
# Epoch 15/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 14s 322ms/step - accuracy: 0.6933 - loss: 0.6979 - val_accuracy: 0.5694 - val_loss: 1.1144
# Epoch 16/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 14s 302ms/step - accuracy: 0.7743 - loss: 0.5979 - val_accuracy: 0.6944 - val_loss: 0.7422
# Epoch 17/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 14s 304ms/step - accuracy: 0.7897 - loss: 0.5089 - val_accuracy: 0.7500 - val_loss: 0.5830
# Epoch 18/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 21s 291ms/step - accuracy: 0.7786 - loss: 0.5587 - val_accuracy: 0.6111 - val_loss: 0.8648
# Epoch 19/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 20s 300ms/step - accuracy: 0.7654 - loss: 0.5303 - val_accuracy: 0.5417 - val_loss: 0.8791
# Epoch 20/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 13s 294ms/step - accuracy: 0.7603 - loss: 0.5136 - val_accuracy: 0.6806 - val_loss: 0.9122
# Epoch 21/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 13s 296ms/step - accuracy: 0.8010 - loss: 0.5272 - val_accuracy: 0.7222 - val_loss: 0.6233
# Epoch 22/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 21s 301ms/step - accuracy: 0.7770 - loss: 0.5831 - val_accuracy: 0.8056 - val_loss: 0.5771
# Epoch 23/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 14s 307ms/step - accuracy: 0.7854 - loss: 0.5139 - val_accuracy: 0.7083 - val_loss: 0.7025
# Epoch 24/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 13s 296ms/step - accuracy: 0.7869 - loss: 0.5410 - val_accuracy: 0.8472 - val_loss: 0.4854
# Epoch 25/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 20s 262ms/step - accuracy: 0.8025 - loss: 0.5088 - val_accuracy: 0.6667 - val_loss: 0.7989
# Epoch 26/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 21s 300ms/step - accuracy: 0.7751 - loss: 0.5146 - val_accuracy: 0.7500 - val_loss: 0.7203
# Epoch 27/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 19s 270ms/step - accuracy: 0.7989 - loss: 0.4764 - val_accuracy: 0.6944 - val_loss: 0.7423
# Epoch 28/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 21s 297ms/step - accuracy: 0.8005 - loss: 0.4894 - val_accuracy: 0.7500 - val_loss: 0.5910
# Epoch 29/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 13s 299ms/step - accuracy: 0.8086 - loss: 0.4612 - val_accuracy: 0.7361 - val_loss: 0.7514
# Epoch 30/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 20s 265ms/step - accuracy: 0.8458 - loss: 0.3798 - val_accuracy: 0.7917 - val_loss: 0.6712
# Epoch 31/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 14s 276ms/step - accuracy: 0.8405 - loss: 0.4185 - val_accuracy: 0.7083 - val_loss: 0.9260
# Epoch 32/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 20s 296ms/step - accuracy: 0.8305 - loss: 0.4173 - val_accuracy: 0.7917 - val_loss: 0.6513
# Epoch 33/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 14s 304ms/step - accuracy: 0.8501 - loss: 0.4308 - val_accuracy: 0.7778 - val_loss: 0.6537
# Epoch 34/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 21s 289ms/step - accuracy: 0.8689 - loss: 0.3674 - val_accuracy: 0.7917 - val_loss: 0.6035
# Epoch 35/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 14s 272ms/step - accuracy: 0.8308 - loss: 0.3997 - val_accuracy: 0.7639 - val_loss: 0.8025
# Epoch 36/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 14s 289ms/step - accuracy: 0.8373 - loss: 0.4060 - val_accuracy: 0.8750 - val_loss: 0.5545
# Epoch 37/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 13s 303ms/step - accuracy: 0.8100 - loss: 0.4315 - val_accuracy: 0.8333 - val_loss: 0.6119
# Epoch 38/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 13s 297ms/step - accuracy: 0.8435 - loss: 0.4162 - val_accuracy: 0.8194 - val_loss: 0.4851
# Epoch 39/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 14s 313ms/step - accuracy: 0.8590 - loss: 0.4004 - val_accuracy: 0.7917 - val_loss: 0.6366
# Epoch 40/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 13s 294ms/step - accuracy: 0.7782 - loss: 0.4679 - val_accuracy: 0.7917 - val_loss: 0.6816
# Epoch 41/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 20s 271ms/step - accuracy: 0.8567 - loss: 0.3835 - val_accuracy: 0.8056 - val_loss: 0.6276
# Epoch 42/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 21s 296ms/step - accuracy: 0.8697 - loss: 0.3870 - val_accuracy: 0.7917 - val_loss: 0.7074
# Epoch 43/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 13s 299ms/step - accuracy: 0.8625 - loss: 0.4044 - val_accuracy: 0.8472 - val_loss: 0.5537
# Epoch 44/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 14s 305ms/step - accuracy: 0.8883 - loss: 0.2993 - val_accuracy: 0.7639 - val_loss: 0.6329
# Epoch 45/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 13s 299ms/step - accuracy: 0.8541 - loss: 0.3523 - val_accuracy: 0.7917 - val_loss: 0.6816
# Epoch 46/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 13s 288ms/step - accuracy: 0.8539 - loss: 0.3625 - val_accuracy: 0.8472 - val_loss: 0.5406
# Epoch 47/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 13s 290ms/step - accuracy: 0.8942 - loss: 0.3018 - val_accuracy: 0.8750 - val_loss: 0.5248
# Epoch 48/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 13s 284ms/step - accuracy: 0.8583 - loss: 0.3357 - val_accuracy: 0.8056 - val_loss: 0.5525
# Epoch 49/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 13s 279ms/step - accuracy: 0.8790 - loss: 0.3599 - val_accuracy: 0.7361 - val_loss: 0.7384
# Epoch 50/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 12s 259ms/step - accuracy: 0.8844 - loss: 0.2940 - val_accuracy: 0.8194 - val_loss: 0.5133
# Epoch 51/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 13s 273ms/step - accuracy: 0.8559 - loss: 0.3499 - val_accuracy: 0.8472 - val_loss: 0.5414
# Epoch 52/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 20s 297ms/step - accuracy: 0.8602 - loss: 0.3362 - val_accuracy: 0.7778 - val_loss: 0.5981
# Epoch 53/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 13s 297ms/step - accuracy: 0.9082 - loss: 0.2750 - val_accuracy: 0.8472 - val_loss: 0.5570
# Epoch 54/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 13s 291ms/step - accuracy: 0.8935 - loss: 0.2650 - val_accuracy: 0.8472 - val_loss: 0.5071
# Epoch 55/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 13s 290ms/step - accuracy: 0.8822 - loss: 0.2934 - val_accuracy: 0.8333 - val_loss: 0.6781
# Epoch 56/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 21s 281ms/step - accuracy: 0.8939 - loss: 0.2923 - val_accuracy: 0.7917 - val_loss: 0.7346
# Epoch 57/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 20s 302ms/step - accuracy: 0.9228 - loss: 0.2346 - val_accuracy: 0.8333 - val_loss: 0.6948
# Epoch 58/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 20s 269ms/step - accuracy: 0.9103 - loss: 0.2464 - val_accuracy: 0.8056 - val_loss: 0.6471
# Epoch 59/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 13s 288ms/step - accuracy: 0.9052 - loss: 0.2644 - val_accuracy: 0.8333 - val_loss: 0.6760
# Epoch 60/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 20s 294ms/step - accuracy: 0.8583 - loss: 0.3781 - val_accuracy: 0.8194 - val_loss: 0.6059
# Epoch 61/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 13s 298ms/step - accuracy: 0.9330 - loss: 0.1999 - val_accuracy: 0.7917 - val_loss: 0.7742
# Epoch 62/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 13s 300ms/step - accuracy: 0.8846 - loss: 0.3152 - val_accuracy: 0.8056 - val_loss: 0.6980
# Epoch 63/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 13s 287ms/step - accuracy: 0.8847 - loss: 0.2721 - val_accuracy: 0.8056 - val_loss: 0.9213
# Epoch 64/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 21s 310ms/step - accuracy: 0.8920 - loss: 0.2489 - val_accuracy: 0.7500 - val_loss: 0.8589
# Epoch 65/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 20s 294ms/step - accuracy: 0.8997 - loss: 0.2478 - val_accuracy: 0.7639 - val_loss: 1.1032
# Epoch 66/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 20s 296ms/step - accuracy: 0.8779 - loss: 0.3174 - val_accuracy: 0.7917 - val_loss: 0.9757
# Epoch 67/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 14s 302ms/step - accuracy: 0.9250 - loss: 0.2048 - val_accuracy: 0.8056 - val_loss: 0.8706
# Epoch 68/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 13s 294ms/step - accuracy: 0.8995 - loss: 0.2705 - val_accuracy: 0.8194 - val_loss: 0.8200
# Epoch 69/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 20s 277ms/step - accuracy: 0.9318 - loss: 0.1979 - val_accuracy: 0.8472 - val_loss: 0.8707
# Epoch 70/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 21s 294ms/step - accuracy: 0.9078 - loss: 0.2368 - val_accuracy: 0.8750 - val_loss: 0.7152
# Epoch 71/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 13s 302ms/step - accuracy: 0.8983 - loss: 0.2939 - val_accuracy: 0.8750 - val_loss: 0.6276
# Epoch 72/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 19s 270ms/step - accuracy: 0.9203 - loss: 0.2000 - val_accuracy: 0.8194 - val_loss: 0.7142
# Epoch 73/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 13s 266ms/step - accuracy: 0.9385 - loss: 0.1829 - val_accuracy: 0.8472 - val_loss: 0.6907
# Epoch 74/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 13s 269ms/step - accuracy: 0.8964 - loss: 0.3201 - val_accuracy: 0.8472 - val_loss: 0.7096
# Epoch 75/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 21s 308ms/step - accuracy: 0.9278 - loss: 0.2461 - val_accuracy: 0.8056 - val_loss: 0.8048
# Epoch 76/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 13s 295ms/step - accuracy: 0.9202 - loss: 0.2368 - val_accuracy: 0.8611 - val_loss: 0.6124
# Epoch 77/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 20s 264ms/step - accuracy: 0.9308 - loss: 0.2094 - val_accuracy: 0.8611 - val_loss: 0.5596
# Epoch 78/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 13s 262ms/step - accuracy: 0.9164 - loss: 0.2538 - val_accuracy: 0.8611 - val_loss: 0.5019
# Epoch 79/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 13s 257ms/step - accuracy: 0.9145 - loss: 0.2259 - val_accuracy: 0.8472 - val_loss: 0.7381
# Epoch 80/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 20s 291ms/step - accuracy: 0.8814 - loss: 0.2998 - val_accuracy: 0.7917 - val_loss: 1.0351
# Epoch 81/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 20s 257ms/step - accuracy: 0.8762 - loss: 0.3027 - val_accuracy: 0.8611 - val_loss: 0.5839
# Epoch 82/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 13s 260ms/step - accuracy: 0.8942 - loss: 0.2192 - val_accuracy: 0.8750 - val_loss: 0.6486
# Epoch 83/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 21s 302ms/step - accuracy: 0.9083 - loss: 0.2123 - val_accuracy: 0.8194 - val_loss: 0.6687
# Epoch 84/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 20s 265ms/step - accuracy: 0.9169 - loss: 0.2349 - val_accuracy: 0.8472 - val_loss: 0.6147
# Epoch 85/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 21s 297ms/step - accuracy: 0.9242 - loss: 0.2033 - val_accuracy: 0.8611 - val_loss: 0.6130
# Epoch 86/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 13s 294ms/step - accuracy: 0.9050 - loss: 0.2401 - val_accuracy: 0.8472 - val_loss: 0.6618
# Epoch 87/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 13s 296ms/step - accuracy: 0.9381 - loss: 0.1817 - val_accuracy: 0.8333 - val_loss: 0.8130
# Epoch 88/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 20s 264ms/step - accuracy: 0.9214 - loss: 0.2072 - val_accuracy: 0.8194 - val_loss: 0.7758
# Epoch 89/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 21s 297ms/step - accuracy: 0.9258 - loss: 0.2057 - val_accuracy: 0.8750 - val_loss: 0.7145
# Epoch 90/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 20s 268ms/step - accuracy: 0.9427 - loss: 0.1648 - val_accuracy: 0.8611 - val_loss: 0.7531
# Epoch 91/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 14s 274ms/step - accuracy: 0.9224 - loss: 0.2314 - val_accuracy: 0.8611 - val_loss: 0.6473
# Epoch 92/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 20s 296ms/step - accuracy: 0.9380 - loss: 0.1670 - val_accuracy: 0.8472 - val_loss: 0.6908
# Epoch 93/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 20s 268ms/step - accuracy: 0.9232 - loss: 0.2037 - val_accuracy: 0.8611 - val_loss: 0.5833
# Epoch 94/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 14s 282ms/step - accuracy: 0.9387 - loss: 0.1799 - val_accuracy: 0.8194 - val_loss: 1.0293
# Epoch 95/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 20s 304ms/step - accuracy: 0.9257 - loss: 0.2220 - val_accuracy: 0.8194 - val_loss: 0.9443
# Epoch 96/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 20s 272ms/step - accuracy: 0.8938 - loss: 0.2400 - val_accuracy: 0.8333 - val_loss: 0.6781
# Epoch 97/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 21s 302ms/step - accuracy: 0.9281 - loss: 0.1937 - val_accuracy: 0.8611 - val_loss: 0.5042
# Epoch 98/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 19s 272ms/step - accuracy: 0.9042 - loss: 0.2272 - val_accuracy: 0.8333 - val_loss: 0.6762
# Epoch 99/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 13s 273ms/step - accuracy: 0.9413 - loss: 0.1815 - val_accuracy: 0.8056 - val_loss: 0.7155
# Epoch 100/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 20s 294ms/step - accuracy: 0.9301 - loss: 0.2139 - val_accuracy: 0.8472 - val_loss: 0.6193

# %%
loss, acc = model.evaluate(test_data,verbose = 1)
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 220s 12s/step - accuracy: 0.8608 - loss: 0.3796

# %%
import seaborn as sns
predictions_prob = model.predict(test_data)
predictions = np.argmax(predictions_prob , axis = 1)
true_label = test_data.classes
report = classification_report(true_label,predictions)
print(report)
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 5s 187ms/step
#               precision    recall  f1-score   support
#
#            0       0.82      0.86      0.84       120
#            1       0.86      0.75      0.80        51
#            2       1.00      0.94      0.97        54
#            3       0.83      0.88      0.85        90
#
#     accuracy                           0.86       315
#    macro avg       0.88      0.86      0.87       315
# weighted avg       0.86      0.86      0.86       315

# %%
conf_mat = confusion_matrix(true_label,predictions)
sns.heatmap(conf_mat ,fmt='g',annot = True , cmap='Blues' , xticklabels=test_classes , yticklabels = test_classes,)
plt.xlabel('Predictions')
plt.ylabel('True label')
plt.title('Confusion Matrix')
plt.xticks(rotation = 45)
plt.show()

# %%
res = results.history
train_acc = res['accuracy']
val_accuracy = res['val_accuracy']
epochs = range(1, len(train_acc) + 1)

line1 = plt.plot(epochs, val_accuracy, label = 'Validation/Test Accuracy')
line2 = plt.plot(epochs, train_acc, label = 'Training Accuracy')

plt.setp(line1, linewidth = 1.8, marker = 'o', markersize = 6.5)
plt.setp(line2, linewidth = 1.8, marker = 's', markersize = 5)
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()
plt.show()

# %%
res = results.history
train_loss = res['loss']
val_loss = res['val_loss']
epochs = range(1, len(train_loss) + 1)

line1 = plt.plot(epochs, val_loss, label = 'Validation/Test Loss')
line2 = plt.plot(epochs, train_loss, label = 'Training Loss')

plt.setp(line1, linewidth = 1.8, marker = 'o', markersize = 6.5)
plt.setp(line2, linewidth = 1.8, marker = 's', markersize = 5)
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()
plt.show()
